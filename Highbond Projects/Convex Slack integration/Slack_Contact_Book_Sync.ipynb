# %%
V_RESULTS_TABLE_ID: int = 114615

# %%
import requests, pandas as pd

v_hb_token = "32fd2b128e98b2375daf247d0710c90d8c62b9422589332f4ef9ed5df8c48895"
"""
# Checking user input variables. If they're not provided, raise exception and terminate script.
if len(hcl.secret["v_hb_token"].unmask()) == 0:
    raise KeyError("HighBond token not provided.")
if len(hcl.secret["V_SLACK_TOKEN"].unmask()) == 0:
    raise KeyError("Slack token not provided.")
"""

#request config
request_headers: dict = {
    "Authorization": "Bearer xoxb-975869316710-3136462900515-o7A66jusV3FUzGcohQxnsI2F" #Convex
#    "Authorization": "Bearer xoxb-2050332499077-2766324017669-oEarutEqWHK9jQbK2RbNANe8" #Akos
#   "Authorization": "Bearer {}".format(hcl.secret["V_SLACK_TOKEN"].unmask())
}

slack_url: str = "https://slack.com/api/users.list"

#fetch and prepare user list from Slack
request_response = requests.request("GET", slack_url, headers = request_headers)
if request_response.status_code != 200:
    raise ConnectionError(f"Could not connect to Slack ({request_response.url}) to retrieve Users. Error code: {request_response.status_code}, Reason: {request_response.text}")

slack_users_dict = request_response.json()
if not slack_users_dict["ok"]:
    raise ConnectionError(f"Could not connect to Slack ({request_response.url}) to retrieve Users. Error code: {request_response.status_code}, Reason: {request_response.text}")

slack_users_df = pd.json_normalize(slack_users_dict["members"])

# renaming fields
slack_users_df["Slack ID"] = slack_users_df["id"]
slack_users_df["Name"] = slack_users_df["profile.real_name"]
slack_users_df["Email"] = slack_users_df["profile.email"]

slack_users_df_final = slack_users_df[slack_users_df["Email"].notnull()]
slack_users_df_final = slack_users_df_final[slack_users_df_final["deleted"].eq(False)]
slack_users_df_final = slack_users_df_final[["Name","Email","Slack ID"]].reset_index(drop=True)
slack_users_df_final
# Out:
#                          Name                                     Email  \
# 0              David Burridge       david.burridge@convexin.engineering
# 1                  Cavan Lang           cavan.lang@convexin.engineering
# 2         Alistair2 McGlinchy                   alistair2@mcglinchy.org
# 3          Alistair McGlinchy   alistair.mcglinchy@convexin.engineering
# 4                  Rick Leach           rick.leach@convexin.engineering
# 5                  Skipp Barr                   skip.barr@netfoundry.io
# 6                Ben Ferandez        ben.fernandez@convexin.engineering
# 7              Giovanni Bazan       giovanni.bazan@convexin.engineering
# 8                Michael Earl         michael.earl@convexin.engineering
# 9              JumpCloud Sync       jumpcloud.sync@convexin.engineering
# 10            Zscaler Service      zscaler.service@convexin.engineering
# 11  Alistair (Prod) McGlinchy           alistair.mcglinchy@convexin.com
# ...

# %%
# Exporting final dataframe to Results
results_hcl_df = hcl.from_pandas(slack_users_df_final)
export_result = results_hcl_df.to_hb_results(table_id = str(V_RESULTS_TABLE_ID), overwrite = True)
print("Highbond Contact Book updated sucessfully (with status code", export_result, ")")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28380/340738471.py in <module>
#       1 # Exporting final dataframe to Results
# ----> 2 results_hcl_df = hcl.from_pandas(slack_users_df_final)
#       3 export_result = results_hcl_df.to_hb_results(table_id = str(V_RESULTS_TABLE_ID), overwrite = True)
#       4 print("Highbond Contact Book updated sucessfully (with status code ", export_result, ")")
#
# NameError: name 'hcl' is not defined
