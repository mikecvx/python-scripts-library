# %%
import pandas
import json
import requests
import datetime

pandas.set_option("display.max_columns", None)


# Set the variables
ORG_ID = 32874
ASSET_TYPE_ID = 1087864
ASSET_STATUS = ["Open (Pending Conditions & Attestation)"]

# URL API
api_env = "https://apis-eu.highbond.com/v1/orgs/" + str(ORG_ID)

# Headers
request_headers = {
#   "Authorization": "Bearer {}".format(hcl.secret["v_hb_token"].unmask()),
    "Authorization": "Bearer ee93272f8f8e718d9e7ad027f2f13e0eb345c938709d9ac759821b152ee709cc",
    "Content-Type": "application/vnd.api+json",
    "Accept-encoding": ""
}

# %%
# Helper function to handle pagination and grab all objects rather than just one page of objects
def highbond_api_get_all(resource_url_body):
    try:
        get_response = requests.get(api_env + resource_url_body, headers=request_headers)
        get_response.raise_for_status()
        print("Get assets response: ", get_response, "\n")
    except requests.exceptions.RequestException as get_err:
        print(get_err.get_response.text)
        raise SystemExit(get_err)
    except requests.exceptions.HTTPError as get_err:
        print(get_err.get_response.text)
        raise SystemExit(get_err)
    
    response_json = get_response.json()
    list_of_result_dicts = response_json["data"]
    while get_response.status_code == 200:
        if response_json["links"]["next"] and len(response_json["links"]["next"]) > 0 and resource_url_body != response_json["links"]["next"]:
            try:
                get_response = requests.get(api_env + response_json["links"]["next"], headers=request_headers)
                get_response.raise_for_status()
                print("\nGet assets loop response: ", get_response, "\n")
            except requests.exceptions.RequestException as get_err:
                print(get_err.get_response.text)
                raise SystemExit(get_err)
            except requests.exceptions.HTTPError as get_err:
                print(get_err.get_response.text)
                raise SystemExit(get_err)
            
            response_json = get_response.json()
            list_of_result_dicts.extend(response_json["data"])
            
        else:
            break
    
    return list_of_result_dicts



# Helper function to handle asset attribute update
def highbond_asset_get_update(resource_url_body):
    try:
        get_response = requests.get(api_env + resource_url_body, headers=request_headers)
        get_response.raise_for_status()
        print("\nGet specific asset response: ", get_response, "\n")
    except requests.exceptions.RequestException as get_err:
        print(get_err.get_response.text)
        raise SystemExit(get_err)
    except requests.exceptions.HTTPError as get_err:
        print(get_err.get_response.text)
        raise SystemExit(get_err)
    
    list_of_result_dicts = get_response.json()

    # Create a new dict for the update with the required attribute only
    asset_dicts = {}
    asset_dicts["data"] = {}
    asset_dicts["data"]["type"] = list_of_result_dicts["data"]["type"]
    asset_dicts["data"]["id"] = list_of_result_dicts["data"]["id"]
    asset_dicts["data"]["attributes"] = {}
    asset_dicts["data"]["attributes"]["asset_attributes"] = [list_of_result_dicts["data"]["attributes"]["asset_attributes"][index_review], list_of_result_dicts["data"]["attributes"]["asset_attributes"][index_expiry]]
    print("\nRelevant asset dict: \n", asset_dicts)

    # Create the updated attribute
    asset_dicts["data"]["attributes"]["asset_attributes"][1]["value"] = [(datetime.datetime.strptime(asset_dicts["data"]["attributes"]["asset_attributes"][0]["value"][0],"%Y-%m-%dT%H:%M:%S.%fZ") + pandas.DateOffset(months=6)).strftime("%Y-%m-%dT%H:%M:%S.%f")[:-3] + "Z"]
    print("\nOld value: ", asset_dicts["data"]["attributes"]["asset_attributes"][0]["value"])
    print("New value: ", asset_dicts["data"]["attributes"]["asset_attributes"][1]["value"])
    
    # Update the value in Highbond asset
    try:
        patch_response = requests.patch(api_env + resource_url_body, json.dumps(dict(asset_dicts)), headers=request_headers)
        patch_response.raise_for_status()
        print("\nPatch specific asset response: ", patch_response)
    except requests.exception.RequestExceptino as patch_err:
        print(patch_err.patch_response.text)
        raise SystemExit(patch_err)
    except requests.exceptions.HTTPError as patch_err:
        print(patch_err.patch_response.text)
        raise SystemExit(patch_err)
    
    return

# %%
# Grab list of all assets and filter them for the relevant ones
assets_list = highbond_api_get_all("/asset_types/" + str(ASSET_TYPE_ID) + "/assets")

if ASSET_STATUS:
    assets_list_filtered = [asset for asset in assets_list if asset["attributes"]["asset_attributes"][5]["value"]["name"].strip() in ASSET_STATUS]
else:
    assets_list_filtered = assets_list

try:
    print(assets_list_filtered[0])
    
    # Create Assets Dataframe
    assets_df = pandas.json_normalize(assets_list_filtered)
    assets_df
    print("\n")
    print("-"*100)


    # Get and Update the assets where there is data
    for asset in assets_list_filtered:
        # Get the review and expiry dates field dynamically
        i_review = 0
        i_expiry = 0
        for attribute in asset["attributes"]["asset_attributes"]:
            if attribute["field_name"] == "unit_rrap_actual_review_date_(required)":
                index_review = i_review
                i_review += 1
                i_expiry += 1
            elif attribute["field_name"] == "unit_rrap_approval_expiry_date_(required)":
                index_expiry = i_expiry
                i_review += 1
                i_expiry += 1
            else:
                i_review += 1
                i_expiry += 1
                
                
        if asset["attributes"]["asset_attributes"][index_review]["value"] is None:
            print(str(ASSET_TYPE_ID), "is not set, hence not processed.")
            continue
        else:
            print("\n")
            print("-"*100)
            print("\nAsset ID to update: ", asset["id"])
            highbond_asset_get_update("/asset_types/" + str(ASSET_TYPE_ID) + "/assets/" + str(asset["id"]))
            print("\nAsset ID updated: ", asset["id"])
            print("-"*100)
            print("\n")

    print("\n\n\nRobot Task Run Completed!\n\n\n")

except IndexError as err:
    print("\nWarning: No asset found for workflow status: ", ASSET_STATUS, ". Task run terminated.\n")
except:
    raise SystemExit("\nError in getting the assets. Task run terminated.\n")
# Out:
# Get assets response:  <Response [200]>
#
#
# Get assets loop response:  <Response [200]>
#
# {'type': 'assets', 'id': '1574203499185430', 'attributes': {'asset_attributes': [{'field_name': 'metadata.created_at', 'value': ['2022-01-14T09:00:16.305Z']}, {'field_name': 'metadata.created_by', 'value': {'user_ids': ['xbZMnbxhuyj5KfW2yMi1'], 'group_ids': []}}, {'field_name': 'metadata.id', 'value': ['1574203499185430']}, {'field_name': 'metadata.updated_at', 'value': ['2022-02-10T11:19:39.780Z']}, {'field_name': 'metadata.updated_by', 'value': {'user_ids': ['QjDrgiy26sxEByeSaiva'], 'group_ids': []}}, {'field_name': 'metadata.workflow_status', 'value': {'id': '04e5ce22-f632-435d-b9e5-bcf290a40f57', 'name': 'Open (Pending Conditions & Attestation)'}}, {'field_name': 'region', 'value': None}, {'field_name': 'business_division', 'value': None}, {'field_name': 'business_area', 'value': None}, {'field_name': 'countries_impacted', 'value': None}, {'field_name': 'legal_entity', 'value': None}, {'field_name': 'secondary_regions', 'value': None}, {'field_name': 'name', 'value': ['Tracy Test']}, {'field_name': 'requester_name_(required)', 'value': {'user_ids': ['xbZMnbxhuyj5KfW2yMi1'], 'group_ids': []}}, {'field_name': 'dws_executive_board_sponsor_(required)', 'value': {'user_ids': ['xbZMnbxhuyj5KfW2yMi1'], 'group_ids': []}}, {'field_name': 'le_board_sponsor_(required)', 'value': {'user_ids': ['xbZMnbxhuyj5KfW2yMi1'], 'group_ids': []}}, {'field_name': 'business_sponsor_(required)', 'value': {'user_ids': ['xbZMnbxhuyj5KfW2yMi1'], 'group_ids': []}}, {'field_name': 'principal_business_contacts_(required)', 'value': {'user_ids': ['xbZMnbxhuyj5KfW2yMi1'], 'group_ids': []}}, {'field_name': 'subject_matter_experts_(required)', 'value': {'user_ids': ['xbZMnbxhuyj5KfW2yMi1'], 'group_ids': []}}, {'field_name': 'mandatory_referral_(required)', 'value': ['Yes']}, {'field_name': 'mandatory_trigger_(required)', 'value': ['Covered Clients']}, {'field_name': 'statement_matter_(required)', 'value': ['<p>texttexttexttexttexttexttexttext</p>']}, {'field_name': 'counterparties_names_(required)', 'value': ['<p>text texttexttexttexttexttexttexttext</p>']}, {'field_name': 'counterparties_details_(required)', 'value': ['<p>texttexttexttexttexttexttexttexttexttexttexttexttexttexttexttext</p>']}, {'field_name': 'details_of_proposed_transaction_(required)', 'value': ['<p>texttexttexttexttexttexttexttexttexttexttexttexttexttexttexttext</p>']}, {'field_name': 'us_nexus_(required)', 'value': ['No']}, {'field_name': 'referral_from_(required)', 'value': ['CAAF']}, {'field_name': 'rationale_for_referral_(required)', 'value': ['<p>texttexttexttexttexttexttexttexttexttexttexttexttexttexttexttext</p>']}, {'field_name': 'summary_of_relevant_financials_(required)', 'value': ['<p>texttexttexttexttexttexttexttexttexttexttexttexttexttexttexttext</p>']}, {'field_name': 'business_rationale_(required)', 'value': ['<p>texttexttexttexttexttexttexttexttexttexttexttexttexttexttexttext</p>']}, {'field_name': 'internal_processes_sign_offs_(required)', 'value': ['<p>texttexttexttexttexttexttexttexttexttexttexttexttexttexttexttext</p>']}, {'field_name': 'proposed_materiality_classification_(required)', 'value': ['Material']}, {'field_name': 'investment_decision_by_portfolio_manager_(required)', 'value': ['Yes']}, {'field_name': 'matter_presented_to_dws_rrc_for_(required)', 'value': ['Approval']}, {'field_name': 'materiality_confirmed_(required)', 'value': ['Confirmed']}, {'field_name': 'sign_off_info_(required)', 'value': ['Confirmed']}, {'field_name': 'information_sharing_(required)', 'value': ['Confirmed']}, {'field_name': 'conflicts_of_interest_(required)', 'value': ['Confirmed']}, {'field_name': 'qa_comment', 'value': None}, {'field_name': 'qa_confirmed_(required)', 'value': ['Confirmed']}, {'field_name': 'unit_rrap_decision_(required)', 'value': ['Approved with conditions']}, {'field_name': 'unit_rrap_final_decision_(required)', 'value': ['DWS SME']}, {'field_name': 'unit_rrap_rationale_(required)', 'value': ['<p>texttexttexttexttexttexttexttexttexttexttexttexttexttexttexttext</p> ...
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# ----------------------------------------------------------------------------------------------------
#
# Asset ID to update:  1574203499185430
#
# Get specific asset response:  <Response [200]>
#
#
# Relevant asset dict:
#  {'data': {'type': 'assets', 'id': '1574203499185430', 'attributes': {'asset_attributes': [{'field_name': 'unit_rrap_actual_review_date_(required)', 'value': ['2022-01-13T09:04:37.781Z']}, {'field_name': 'unit_rrap_approval_expiry_date_(required)', 'value': ['2022-07-13T09:04:37.781Z']}]}}}
#
# Old value:  ['2022-01-13T09:04:37.781Z']
# New value:  ['2022-07-13T09:04:37.781Z']
#
# Patch specific asset response:  <Response [200]>
#
# Asset ID updated:  1574203499185430
# ----------------------------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# Asset ID to update:  1574203602323688
#
# Get specific asset response:  <Response [200]>
#
#
# Relevant asset dict:
#  {'data': {'type': 'assets', 'id': '1574203602323688', 'attributes': {'asset_attributes': [{'field_name': 'unit_rrap_actual_review_date_(required)', 'value': ['2022-01-02T16:15:23.304Z']}, {'field_name': 'unit_rrap_approval_expiry_date_(required)', 'value': ['2022-07-02T16:15:23.304Z']}]}}}
#
# Old value:  ['2022-01-02T16:15:23.304Z']
# New value:  ['2022-07-02T16:15:23.304Z']
#
# Patch specific asset response:  <Response [200]>
#
# Asset ID updated:  1574203602323688
# ----------------------------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# Asset ID to update:  1574203635291043
#
# Get specific asset response:  <Response [200]>
#
#
# Relevant asset dict:
#  {'data': {'type': 'assets', 'id': '1574203635291043', 'attributes': {'asset_attributes': [{'field_name': 'unit_rrap_actual_review_date_(required)', 'value': ['2022-01-18T16:53:13.261Z']}, {'field_name': 'unit_rrap_approval_expiry_date_(required)', 'value': ['2022-07-18T16:53:13.261Z']}]}}}
#
# Old value:  ['2022-01-18T16:53:13.261Z']
# New value:  ['2022-07-18T16:53:13.261Z']
#
# Patch specific asset response:  <Response [200]>
#
# Asset ID updated:  1574203635291043
# ----------------------------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# Asset ID to update:  1574203636994588
#
# Get specific asset response:  <Response [200]>
#
#
# Relevant asset dict:
#  {'data': {'type': 'assets', 'id': '1574203636994588', 'attributes': {'asset_attributes': [{'field_name': 'unit_rrap_actual_review_date_(required)', 'value': ['2022-01-18T16:59:13.569Z']}, {'field_name': 'unit_rrap_approval_expiry_date_(required)', 'value': ['2022-07-18T16:59:13.569Z']}]}}}
#
# Old value:  ['2022-01-18T16:59:13.569Z']
# New value:  ['2022-07-18T16:59:13.569Z']
#
# Patch specific asset response:  <Response [200]>
#
# Asset ID updated:  1574203636994588
# ----------------------------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# Asset ID to update:  1574203671666496
#
# Get specific asset response:  <Response [200]>
#
#
# Relevant asset dict:
#  {'data': {'type': 'assets', 'id': '1574203671666496', 'attributes': {'asset_attributes': [{'field_name': 'unit_rrap_actual_review_date_(required)', 'value': ['2022-02-10T09:41:00.817Z']}, {'field_name': 'unit_rrap_approval_expiry_date_(required)', 'value': ['2022-08-10T09:41:00.817Z']}]}}}
#
# Old value:  ['2022-02-10T09:41:00.817Z']
# New value:  ['2022-08-10T09:41:00.817Z']
#
# Patch specific asset response:  <Response [200]>
#
# Asset ID updated:  1574203671666496
# ----------------------------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# Asset ID to update:  1574203724843949
#
# Get specific asset response:  <Response [200]>
#
#
# Relevant asset dict:
#  {'data': {'type': 'assets', 'id': '1574203724843949', 'attributes': {'asset_attributes': [{'field_name': 'unit_rrap_actual_review_date_(required)', 'value': ['2022-01-21T11:13:14.585Z']}, {'field_name': 'unit_rrap_approval_expiry_date_(required)', 'value': ['2022-07-21T11:13:14.585Z']}]}}}
#
# Old value:  ['2022-01-21T11:13:14.585Z']
# New value:  ['2022-07-21T11:13:14.585Z']
#
# Patch specific asset response:  <Response [200]>
#
# Asset ID updated:  1574203724843949
# ----------------------------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# Asset ID to update:  1574204342332553
#
# Get specific asset response:  <Response [200]>
#
#
# Relevant asset dict:
#  {'data': {'type': 'assets', 'id': '1574204342332553', 'attributes': {'asset_attributes': [{'field_name': 'unit_rrap_actual_review_date_(required)', 'value': ['2022-02-10T09:32:01.344Z']}, {'field_name': 'unit_rrap_approval_expiry_date_(required)', 'value': ['2022-08-10T09:32:01.344Z']}]}}}
#
# Old value:  ['2022-02-10T09:32:01.344Z']
# New value:  ['2022-08-10T09:32:01.344Z']
#
# Patch specific asset response:  <Response [200]>
#
# Asset ID updated:  1574204342332553
# ----------------------------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# Asset ID to update:  1574204394106144
#
# Get specific asset response:  <Response [200]>
#
#
# Relevant asset dict:
#  {'data': {'type': 'assets', 'id': '1574204394106144', 'attributes': {'asset_attributes': [{'field_name': 'unit_rrap_actual_review_date_(required)', 'value': ['2022-02-10T09:39:04.460Z']}, {'field_name': 'unit_rrap_approval_expiry_date_(required)', 'value': ['2022-08-10T09:39:04.460Z']}]}}}
#
# Old value:  ['2022-02-10T09:39:04.460Z']
# New value:  ['2022-08-10T09:39:04.460Z']
#
# Patch specific asset response:  <Response [200]>
#
# Asset ID updated:  1574204394106144
# ----------------------------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
# Asset ID to update:  1574204394707112
#
# Get specific asset response:  <Response [200]>
#
#
# Relevant asset dict:
#  {'data': {'type': 'assets', 'id': '1574204394707112', 'attributes': {'asset_attributes': [{'field_name': 'unit_rrap_actual_review_date_(required)', 'value': ['2022-02-10T10:04:46.630Z']}, {'field_name': 'unit_rrap_approval_expiry_date_(required)', 'value': ['2022-08-10T10:04:46.630Z']}]}}}
#
# Old value:  ['2022-02-10T10:04:46.630Z']
# New value:  ['2022-08-10T10:04:46.630Z']
#
# Patch specific asset response:  <Response [200]>
#
# Asset ID updated:  1574204394707112
# ----------------------------------------------------------------------------------------------------
#
#
#
#
#
# Robot Task Run Completed!
